# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = 'texts_token_length_describe.csv'  # replace with your actual file path
df = pd.read_csv(file_path)

# Display the DataFrame to understand its structure
print(df)

# Choose which statistics to plot, for example, mean and std
# You might want to transpose the DataFrame, depending on how the data is organized
df_transposed = df.set_index('Unnamed: 0').transpose()  # Ensuring index makes sense, adjust as needed

# Plotting
plt.figure(figsize=(10, 6))

# Plot means
df_transposed['mean'].plot(kind='bar', yerr=df_transposed['std'], capsize=4, label='Mean', color='skyblue')


# Optionally, plot other statistics
# df_transposed['max'].plot(kind='bar', label='Max', color='lightcoral', alpha=0.5)
# df_transposed['min'].plot(kind='bar', label='Min', color='lightgreen', alpha=0.5)

# Decorate the plot
plt.title("Summary Statistics For Verse Token Length")
plt.xlabel("Texts")
plt.ylabel("Token Length")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#   Unnamed: 0         Bible     Bible_NT        Quran        Torah        Gita  \
# 0      count  31102.000000  7957.000000  6236.000000  5852.000000  625.000000
# 1       mean     25.475114    22.737967    26.975465    26.903281   33.588800
# 2        std     11.121071     8.492482    19.419784    10.835868   11.425997
# 3        min      2.000000     2.000000     2.000000     4.000000   16.000000
# 4        25%     17.000000    17.000000    13.000000    19.000000   27.000000
# 5        50%     24.000000    22.000000    23.000000    26.000000   31.000000
# 6        75%     32.000000    28.000000    35.000000    34.000000   38.000000
# 7        max     91.000000    68.000000   320.000000    73.000000  132.000000
#
#      Analects
# 0  477.000000
# 1   36.174004
# 2   30.314478
# 3    4.000000
# 4   19.000000
# 5   28.000000
# 6   45.000000
# 7  286.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Load the CSV file
file_path = 'texts_token_length_describe.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)

df = df.drop(columns=['Bible'])

# Display the DataFrame to understand its structure
print(df)

# Assume the first column is the statistics type and index by it
df_transposed = df.set_index('Unnamed: 0').transpose()

# Plotting
plt.figure(figsize=(10, 6))

# Get the number of bars to plot
num_bars = df_transposed.shape[0]

# Create a colormap
colormap = cm.viridis(np.linspace(0, 0.7, num_bars))

# Plot means with Viridis colors
df_transposed['mean'].plot(
    kind='bar',
    yerr=df_transposed['std'],
    capsize=4,
    color=colormap,
    label='Mean'
)

# Decorate the plot
# Decorate the plot
plt.title("Summary Statistics For Verse Token Length")
plt.xlabel("Texts")
plt.ylabel("Token Length")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#   Unnamed: 0     Bible_NT        Quran        Torah        Gita    Analects
# 0      count  7957.000000  6236.000000  5852.000000  625.000000  477.000000
# 1       mean    22.737967    26.975465    26.903281   33.588800   36.174004
# 2        std     8.492482    19.419784    10.835868   11.425997   30.314478
# 3        min     2.000000     2.000000     4.000000   16.000000    4.000000
# 4        25%    17.000000    13.000000    19.000000   27.000000   19.000000
# 5        50%    22.000000    23.000000    26.000000   31.000000   28.000000
# 6        75%    28.000000    35.000000    34.000000   38.000000   45.000000
# 7        max    68.000000   320.000000    73.000000  132.000000  286.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import seaborn as sns

# Load the CSV file
file_path = 'texts_token_length_describe.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)
df = df.drop(columns=['Bible'])

# Display the DataFrame to understand its structure
print(df)

# Assume the first column is the statistics type and index by it
df_transposed = df.set_index('Unnamed: 0').transpose()

# Plotting
plt.figure(figsize=(12, 8))

# Set a seaborn style for a cleaner look
sns.set_style("whitegrid")

# Get the number of bars to plot
num_bars = df_transposed.shape[0]

# Create a colormap
colormap = cm.viridis(np.linspace(0, 0.7, num_bars))

# Plot means with Viridis colors
bars = df_transposed['mean'].plot(
    kind='bar',
    yerr=df_transposed['std'],
    capsize=4,
    color=colormap,
    edgecolor='black',
    linewidth=0.7
)


# plt.title("Summary Statistics For Verse Token Length")
# plt.xlabel("Texts")
# plt.ylabel("Token Length")

# Customize the plot further
plt.title("Summary Statistics For Verse Token Length", fontsize=16, fontweight='bold')
plt.xlabel("Texts", fontsize=13)
plt.ylabel("Token Length", fontsize=13)
plt.xticks(rotation=45, fontsize=11)
plt.yticks(fontsize=11)

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove top and right spines for a cleaner look
sns.despine(left=True, bottom=True)

# Add a legend with a better placement
# plt.legend(["Mean"], fontsize=12, loc='upper right')

# Add data labels on top of the bars
for container in bars.containers:
    bars.bar_label(container, fmt='%.2f', label_type='edge', fontsize=10, padding=3)

# Tight layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#   Unnamed: 0     Bible_NT        Quran        Torah        Gita    Analects
# 0      count  7957.000000  6236.000000  5852.000000  625.000000  477.000000
# 1       mean    22.737967    26.975465    26.903281   33.588800   36.174004
# 2        std     8.492482    19.419784    10.835868   11.425997   30.314478
# 3        min     2.000000     2.000000     4.000000   16.000000    4.000000
# 4        25%    17.000000    13.000000    19.000000   27.000000   19.000000
# 5        50%    22.000000    23.000000    26.000000   31.000000   28.000000
# 6        75%    28.000000    35.000000    34.000000   38.000000   45.000000
# 7        max    68.000000   320.000000    73.000000  132.000000  286.000000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 63
#      58 # Add a legend with a better placement
#      59 # plt.legend(["Mean"], fontsize=12, loc='upper right')
#      60
#      61 # Add data labels on top of the bars
#      62 for container in bars.containers:
# ---> 63     bars.bar_label(container, fmt='%.2f', label_type='edge', fontsize=10, padding=3)
#      65 # Tight layout
#      66 plt.tight_layout()
#
# File ~/RAGenesis/.env/lib/python3.9/site-packages/matplotlib/axes/_axes.py:2833, in Axes.bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
#    2829     return 1 if x >= 0 else -1
#    2831 _api.check_in_list(['edge', 'center'], label_type=label_type)
# -> 2833 bars = container.patches
#    2834 errorbar = container.errorbar
#    2835 datavalues = container.datavalues
#
# AttributeError: 'ErrorbarContainer' object has no attribute 'patches'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import seaborn as sns

# Load the CSV file
file_path = 'texts_token_length_describe.csv'   # Replace with your actual file path
df = pd.read_csv(file_path)
df = df.drop(columns=['Bible'])

# Display the DataFrame to understand its structure
print(df)

# Assume the first column is the statistics type and index by it
df_transposed = df.set_index('Unnamed: 0').transpose()

# Plotting
plt.figure(figsize=(12, 8))

# Set a seaborn style for a cleaner look
sns.set_style("whitegrid")

# Get the number of bars to plot
num_bars = df_transposed.shape[0]

# Create a colormap
colormap = cm.viridis(np.linspace(0.1, 0.7, num_bars))

# Plot means with Viridis colors
bars = df_transposed['mean'].plot(
    kind='bar',
    yerr=df_transposed['std'],
    capsize=4,
    color=colormap,
    edgecolor='black',
    linewidth=0.7
)

# Customize the plot further

# plt.title("Summary Statistics For Verse Token Length")
# plt.xlabel("Texts")
# plt.ylabel("Token Length")

# Customize the plot further
plt.title("Summary Statistics For Verse Token Length", fontsize=16, fontweight='bold')
plt.xlabel("Texts", fontsize=13)
plt.ylabel("Token Length", fontsize=13)
plt.xticks(rotation=45, fontsize=11)
plt.yticks(fontsize=11)
# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove top and right spines for a cleaner look
sns.despine(left=True, bottom=True)

# Add a legend with a better placement
# plt.legend(["Mean"], fontsize=12, loc='upper right')

# Add data labels on top of the bars
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 4,
        yval,
        f'{yval:.2f}',
        va='bottom',  # Align text at the bottom of the bar
        ha='center',  # Center the label horizontally
        fontsize=10,
        color='black'
    )

# Tight layout
plt.tight_layout()
plt.savefig('verse_token_len_stats.png')
# Show the plot
plt.show()
# Out:
#   Unnamed: 0     Bible_NT        Quran        Torah        Gita    Analects
# 0      count  7957.000000  6236.000000  5852.000000  625.000000  477.000000
# 1       mean    22.737967    26.975465    26.903281   33.588800   36.174004
# 2        std     8.492482    19.419784    10.835868   11.425997   30.314478
# 3        min     2.000000     2.000000     4.000000   16.000000    4.000000
# 4        25%    17.000000    13.000000    19.000000   27.000000   19.000000
# 5        50%    22.000000    23.000000    26.000000   31.000000   28.000000
# 6        75%    28.000000    35.000000    34.000000   38.000000   45.000000
# 7        max    68.000000   320.000000    73.000000  132.000000  286.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import seaborn as sns

# Load the CSV file
file_path = 'texts_token_length_describe.csv'   # Replace with your actual file path
# df = pd.read_csv(file_path)
df = pd.read_csv(file_path)
df = df.drop(columns=['Bible'])

# Display the DataFrame to understand its structure
print(df)

# Assume the first column is the statistics type and index by it
df_transposed = df.set_index('Unnamed: 0').transpose()

df_transposed['count'] = df_transposed['count'].apply(lambda x: int(x))
print(df_transposed['count'])

# Plotting
plt.figure(figsize=(12, 8))

# Set a seaborn style for a cleaner look
sns.set_style("whitegrid")

# Get the number of bars to plot
num_bars = df_transposed.shape[0]

# Create a colormap
colormap = cm.viridis(np.linspace(0.1, 0.7, num_bars))

# Plot means with Viridis colors
bars = df_transposed['count'].plot(
    kind='bar',
    # yerr=df_transposed['std'],
    capsize=4,
    color=colormap,
    edgecolor='black',
    linewidth=0.7
)

# Customize the plot further

# plt.title("Summary Statistics For Verse Token Length")
# plt.xlabel("Texts")
# plt.ylabel("Token Length")

# Customize the plot further
plt.title("Verse Count", fontsize=16, fontweight='bold')
plt.xlabel("Texts", fontsize=13)
plt.ylabel("Verse Count", fontsize=13)
plt.xticks(rotation=45, fontsize=11)
plt.yticks(fontsize=11)
# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove top and right spines for a cleaner look
sns.despine(left=True, bottom=True)

# Add a legend with a better placement
# plt.legend(["Mean"], fontsize=12, loc='upper right')

# Add data labels on top of the bars
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 4,
        yval,
        f'{yval:.0f}',
        va='bottom',  # Align text at the bottom of the bar
        ha='center',  # Center the label horizontally
        fontsize=10,
        color='black'
    )

# Tight layout
plt.tight_layout()

plt.savefig('verse_count.png')


# Show the plot
plt.show()
# Out:
#   Unnamed: 0     Bible_NT        Quran        Torah        Gita    Analects
# 0      count  7957.000000  6236.000000  5852.000000  625.000000  477.000000
# 1       mean    22.737967    26.975465    26.903281   33.588800   36.174004
# 2        std     8.492482    19.419784    10.835868   11.425997   30.314478
# 3        min     2.000000     2.000000     4.000000   16.000000    4.000000
# 4        25%    17.000000    13.000000    19.000000   27.000000   19.000000
# 5        50%    22.000000    23.000000    26.000000   31.000000   28.000000
# 6        75%    28.000000    35.000000    34.000000   38.000000   45.000000
# 7        max    68.000000   320.000000    73.000000  132.000000  286.000000
# Bible_NT    7957
# Quran       6236
# Torah       5852
# Gita         625
# Analects     477
# Name: count, dtype: int64

# %%
lengths


[25250, 7957, 6236, 5852, 625, 477]
46397
